# %% [markdown]
# # Revisiting the data filtering now that I have clearer set of test for what I need
#
# In particular, there seem to be several examples where the data filtering that I set-up previously doesn't work

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.pylabtools import figsize

import seaborn as sns
import plotly.express as px

import numpy as np
import pandas as pd
import polars as pl
import sqlite3

import statsmodels.formula.api as smf

# %% [markdown]
# ## Simple checks

# %% [markdown]
# ### Question 1: is the per share factored into the units (uom) column?

# %%
def get_raw_data(year, columns):
    """ Fetch and process all columns from a given year
     """
    #to do: filter only columns that use the correct unit of measure

    con = sqlite3.connect('data/processed/all10k.db')
    query = """ SELECT adsh, tag, ddate, dyear, version, coreg, qtrs, 
                 uom, value, footnote FROM num
                 WHERE (dyear=:year) AND {tagfilters}
            """
    tagfilters = "(" + \
                 " OR ".join([f"tag = :tag{i}" for i in range(len(columns))])\
                 + ")"
    query = query.format(tagfilters=tagfilters)

    params = {f'tag{i}': coli for i, coli in enumerate(columns)}
    params.update(year=str(year))

    data = pd.read_sql_query(query, con, params=params,
                             dtype={'value': float, 'adsh': str})
    return data

data = get_raw_data(2022, ['CommonStockDividendsPerShareDeclared', 'EarningsPerShareDiluted'])

# %%
data['uom'].unique()
# Out:
# array(['USD', 'ZAR', 'CAD'], dtype=object)

# %%
(data['uom'] == 'USD').sum()
# Out:
# 8937

# %% [markdown]
# ### answer:
#
# The per-share units are __not__ taken into account in the uom column: we can filter on uom directly in the query

# %%
data[ data['uom'] != 'USD']
# Out:
#                       adsh                                   tag       ddate  \
# 45    0001628280-22-017109  CommonStockDividendsPerShareDeclared  2022-03-31
# 1178  0000049938-23-000015  CommonStockDividendsPerShareDeclared  2022-12-31
# 1188  0000016875-23-000008  CommonStockDividendsPerShareDeclared  2022-12-31
# 2254  0001062993-22-013882               EarningsPerShareDiluted  2022-02-28
# 4740  0000895728-23-000008               EarningsPerShareDiluted  2022-03-31
# 4741  0000895728-23-000008               EarningsPerShareDiluted  2022-06-30
# 4742  0000895728-23-000008               EarningsPerShareDiluted  2022-09-30
# 4743  0000895728-23-000008               EarningsPerShareDiluted  2022-12-31
# 4744  0000895728-23-000008               EarningsPerShareDiluted  2022-12-31
# 4995  0000016875-23-000008               EarningsPerShareDiluted  2022-12-31
# 5027  0000049938-23-000015               EarningsPerShareDiluted  2022-12-31
# 7817  0000950170-23-029420               EarningsPerShareDiluted  2022-03-31
# 7818  0000950170-23-029420               EarningsPerShareDiluted  2022-06-30
# 7819  0000950170-23-029420               EarningsPerShareDiluted  2022-09-30
# 7820  0000950170-23-029420               EarningsPerShareDiluted  2022-09-30
# 7821  0000950170-23-029420               EarningsPerShareDiluted  2022-12-31
# 7822  0000950170-23-029420               EarningsPerShareDiluted  2022-12-31
#
#      dyear       version coreg qtrs  uom  value footnote
# 45    2022  us-gaap/2021  None    1  ZAR   0.04     None
# 1178  2022  us-gaap/2022  None    4  CAD   1.46     None
# 1188  2022  us-gaap/2022  None    4  CAD   0.76     None
# 2254  2022  us-gaap/2021  None    4  CAD  -0.10     None
# 4740  2022  us-gaap/2022  None    1  CAD   0.95     None
# 4741  2022  us-gaap/2022  None    1  CAD   0.22     None
# 4742  2022  us-gaap/2022  None    1  CAD   0.63     None
# 4743  2022  us-gaap/2022  None    1  CAD  -0.53     None
# 4744  2022  us-gaap/2022  None    4  CAD   1.28     None
# 4995  2022  us-gaap/2022  None    4  CAD   3.77     None
# 5027  2022  us-gaap/2022  None    4  CAD  11.44     None
# 7817  2022  us-gaap/2022  None    4  CAD  -0.79     None
# 7818  2022  us-gaap/2022  None    1  CAD  -5.24     None
# 7819  2022  us-gaap/2022  None    1  CAD  -0.62     None
# 7820  2022  us-gaap/2022  None    2  CAD  -5.47     None
# 7821  2022  us-gaap/2022  None    1  CAD  -0.53     None
# 7822  2022  us-gaap/2022  None    3  CAD  -5.82     None

# %%
from read_data import get_submissions
subs = get_submissions(2022)

# %%
subs.loc['0000950170-23-029420']
# Out:
# cik                                                       1737927
# name                                           CANOPY GROWTH CORP
# period_filed                                  2023-03-31 00:00:00
# prevrpt                                                     False
# url             https://www.sec.gov/ixviewer/ix.html?doc=/Arch...
# Name: 0000950170-23-029420, dtype: object

# %% [markdown]
# ### Are there any coregistrants?

# %%
data[~data['coreg'].isna()]
# Out:
#                       adsh                                   tag       ddate  \
# 171   0001140361-22-045115  CommonStockDividendsPerShareDeclared  2022-08-31
# 248   0001407623-23-000042  CommonStockDividendsPerShareDeclared  2022-12-31
# 685   0001032208-23-000008  CommonStockDividendsPerShareDeclared  2022-12-31
# 895   0001360604-23-000019  CommonStockDividendsPerShareDeclared  2022-07-31
# 940   0000827052-23-000010  CommonStockDividendsPerShareDeclared  2022-12-31
# 999   0000899715-23-000044  CommonStockDividendsPerShareDeclared  2022-12-31
# 1015  0000921825-23-000011  CommonStockDividendsPerShareDeclared  2022-12-31
# 1039  0000899689-23-000010  CommonStockDividendsPerShareDeclared  2022-12-31
# 2991  0001558370-23-003042               EarningsPerShareDiluted  2022-12-31
# 3137  0001407623-23-000042               EarningsPerShareDiluted  2022-12-31
# 3962  0001298675-23-000009               EarningsPerShareDiluted  2022-12-31
# 3979  0001286043-23-000023               EarningsPerShareDiluted  2022-12-31
# 4256  0001656423-23-000013               EarningsPerShareDiluted  2022-12-31
# 4309  0001705696-23-000035               EarningsPerShareDiluted  2022-12-31
# 4501  0001558370-23-002087               EarningsPerShareDiluted  2022-12-31
# 4536  0001558370-23-001840               EarningsPerShareDiluted  2022-03-31
# 4537  0001558370-23-001840               EarningsPerShareDiluted  2022-06-30
# 4538  0001558370-23-001840               EarningsPerShareDiluted  2022-09-30
# 4539  0001558370-23-001840               EarningsPerShareDiluted  2022-12-31
# 4660  0001500217-23-000010               EarningsPerShareDiluted  2022-12-31
# 4666  0001500217-23-000010               EarningsPerShareDiluted  2022-12-31
# 4667  0001500217-23-000010               EarningsPerShareDiluted  2022-09-30
# 4668  0001500217-23-000010               EarningsPerShareDiluted  2022-06-30
# 4669  0001500217-23-000010               EarningsPerShareDiluted  2022-03-31
# 4753  0000899715-23-000044               EarningsPerShareDiluted  2022-12-31
# 4754  0000899715-23-000044               EarningsPerShareDiluted  2022-12-31
# 4785  0000921825-23-000011               EarningsPerShareDiluted  2022-12-31
# 4792  0000920522-23-000005               EarningsPerShareDiluted  2022-12-31
# 4796  0000924901-23-000010               EarningsPerShareDiluted  2022-12-31
# 5211  0000950170-23-004699               EarningsPerShareDiluted  2022-12-31
# 5227  0000950170-23-004235               EarningsPerShareDiluted  2022-12-31
# 5311  0000950170-23-003060               EarningsPerShareDiluted  2022-12-31
# 5571  0001025996-23-000072               EarningsPerShareDiluted  2022-12-31
# 5609  0000950170-23-005259               EarningsPerShareDiluted  2022-12-31
# 8573  0001213900-23-057123               EarningsPerShareDiluted  2022-03-31
#
#      dyear       version                                      coreg qtrs  uom  \
# 171   2022  us-gaap/2022                       RubiconTechnologyInc    0  USD
# 248   2022  us-gaap/2021  RetailOpportunityInvestmentsPartnershipLP    4  USD
# 685   2022  us-gaap/2022              SanDiegoGasAndElectricCompany    4  USD
# 895   2022  us-gaap/2022                HealthcareTrustOfAmericaInc    0  USD
# 940   2022  us-gaap/2022            SouthernCaliforniaEdisonCompany    4  USD
# 999   2022  us-gaap/2022             TangerFactoryOutletCentersInc.    4  USD
# 1015  2022  us-gaap/2022                          FirstIndustrialLP    4  USD
# 1039  2022  us-gaap/2022                            VornadoRealtyLp    4  USD
# 2991  2022  us-gaap/2021                 LathamInvestmentHoldingsLp    4  USD
# 3137  2022  us-gaap/2021  RetailOpportunityInvestmentsPartnershipLP    4  USD
# 3962  2022  us-gaap/2022                 CubesmartLPAndSubsidiaries    4  USD
# 3979  2022  us-gaap/2022                          KiteRealtyGroupLP    4  USD
# 4256  2022  us-gaap/2022         BostonPropertiesLimitedPartnership    4  USD
# 4309  2022  us-gaap/2022                           VICIPropertiesLP    4  USD
# 4501  2022  us-gaap/2022                       DigitalRealtyTrustLP    4  USD
# 4536  2022  us-gaap/2022       SimonPropertyGroupLimitedPartnership    1  USD
# 4537  2022  us-gaap/2022       SimonPropertyGroupLimitedPartnership    1  USD
# 4538  2022  us-gaap/2022       SimonPropertyGroupLimitedPartnership    1  USD
# 4539  2022  us-gaap/2022       SimonPropertyGroupLimitedPartnership    1  USD
# 4660  2022  us-gaap/2022                    AmericanAssetsTrustL.P.    4  USD
# 4666  2022  us-gaap/2022                    AmericanAssetsTrustL.P.    1  USD
# 4667  2022  us-gaap/2022                    AmericanAssetsTrustL.P.    1  USD
# 4668  2022  us-gaap/2022                    AmericanAssetsTrustL.P.    1  USD
# 4669  2022  us-gaap/2022                    AmericanAssetsTrustL.P.    1  USD
# 4753  2022  us-gaap/2022             TangerFactoryOutletCentersInc.    4  USD
# 4754  2022  us-gaap/2022         TangerPropertiesLimitedPartnership    4  USD
# 4785  2022  us-gaap/2022                          FirstIndustrialLP    4  USD
# 4792  2022  us-gaap/2022                         EssexPortfolioL.P.    4  USD
# 4796  2022  us-gaap/2022                         VerisResidentialLP    4  USD
# 5211  2022  us-gaap/2022                                  AIMCOOPLP    4  USD
# 5227  2022  us-gaap/2022                                        Cnk    4  USD
# 5311  2022  us-gaap/2022                                      ERPOP    4  USD
# 5571  2022  us-gaap/2022                           KilroyRealtyL.P.    4  USD
# 5609  2022  us-gaap/2022                      ApartmentIncomeReitLP    4  USD
# 8573  2022  us-gaap/2023              GoldenstoneAcquisitionLimited    4  USD
#
#         value footnote
# 171   11.0000     None
# 248    0.5600     None
# 685    0.8600     None
# 895    4.8200     None
# 940    3.0468     None
# 999    0.8025     None
# 1015   1.1800     None
# 1039   2.1200     None
# 2991  -0.0500     None
# 3137   0.4200     None
# 3962   1.2900     None
# 3979  -0.0600     None
# 4256   5.4700     None
# 4309   1.2600     None
# 4501   1.1200     None
# 4536   1.3000     None
# 4537   1.5100     None
# 4538   1.6500     None
# 4539   2.0600     None
# 4660   0.7200     None
# 4666   0.1600     None
# 4667   0.2100     None
# 4668   0.1800     None
# 4669   0.1800     None
# 4753   0.7700     None
# 4754   0.7700     None
# 4785   2.7200     None
# 4792   6.2700     None
# 4796  -0.6300     None
# 5211   0.4900     None
# 5227  -2.2600     None
# 5311   2.0500     None
# 5571   1.9700     None
# 5609   5.8100     None
# 8573  -0.1900     None

# %%
data[data['qtrs'] != '4']
# Out:
#                       adsh                                   tag       ddate  \
# 4     0001564590-22-007169  CommonStockDividendsPerShareDeclared  2022-01-31
# 5     0001564590-22-011817  CommonStockDividendsPerShareDeclared  2022-03-31
# 8     0001558370-22-002442  CommonStockDividendsPerShareDeclared  2022-01-31
# 9     0001558370-22-002442  CommonStockDividendsPerShareDeclared  2022-01-31
# 10    0001558370-22-002585  CommonStockDividendsPerShareDeclared  2022-02-28
# ...                    ...                                   ...         ...
# 8929  0001901606-23-000093               EarningsPerShareDiluted  2022-09-30
# 8932  0000032604-23-000044               EarningsPerShareDiluted  2022-03-31
# 8933  0000032604-23-000044               EarningsPerShareDiluted  2022-06-30
# 8934  0000032604-23-000044               EarningsPerShareDiluted  2022-09-30
# 8936  0000032604-23-000044               EarningsPerShareDiluted  2022-12-31
#
#      dyear       version coreg qtrs  uom  value footnote
# 4     2022  us-gaap/2021  None    0  USD   0.24     None
# 5     2022  us-gaap/2021  None    0  USD   0.09     None
# 8     2022  us-gaap/2021  None    0  USD   0.05     None
# 9     2022  us-gaap/2021  None    3  USD   0.20     None
# 10    2022  us-gaap/2021  None    0  USD   0.09     None
# ...    ...           ...   ...  ...  ...    ...      ...
# 8929  2022  us-gaap/2023  None    2  USD   0.30     None
# 8932  2022  us-gaap/2023  None    1  USD   1.13     None
# 8933  2022  us-gaap/2023  None    1  USD   1.54     None
# 8934  2022  us-gaap/2023  None    1  USD   1.24     None
# 8936  2022  us-gaap/2023  None    1  USD   3.97     None
#
# [2388 rows x 10 columns]

# %% [markdown]
# #### Additional filtering
#
# It is worth looking into which of the coregistrants have a parent reported as well, and which entries for single quarters have a 4 quarter as well.
#
# The main question here is what we want to filter out right away at the query stage.
# - __uom:__ I think any reports that are not in dollars are not helpful to see in the table. These should be filtered.
# - __qtrs:__ There is a case that companies that report only a couple of quarters shouldn't have their data filtered if these companies have only been listed for less than a year. It should, however, be noted as such.
# - __coreg:__ I really can't think of a case where I would want to see the financials of child companies but not their parent companies... leaning toward filtering out all such data.

# %% [markdown]
# ## Looking into special cases:
#
# These cases all cover a specific problem: companies can report a fact multiple ways, or report sub-facts. For example, `MinorityInterest` and `RedeemableNoncontrollingInterestEquityCarryingAmount` could be reported alone, or, both reported because `RedeemableNoncontrolling...` is a sub item of `MinorityInterest`
#
# 1. Apple Inc
# 2. General Mills
# 3. EUROPEAN WAX CENTER, INC
# 4. Cheveron balance sheet - non-controlling interest carrying amount is double counted

# %%
from read_data import get_numbers, get_submissions

year = 2022

def balance_data():
    balance_cols = ['Assets', 'Liabilities', 'StockholdersEquity',
                    'AssetsCurrent', 'LiabilitiesCurrent',
                    'CurrentAssets/Liabilities', 'WorkingCapital/Debt',
                    ]
    
    validation_cols = [
                    'LiabilitiesAndStockholdersEquity',
                    'StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest',
                    ]
    
    minority_equity_cols = [
                    'MinorityInterest',
                    'NonredeemableNoncontrollingInterest',
                    'RedeemableNoncontrollingInterestEquityCommonCarryingAmount',
                    'RedeemableNoncontrollingInterestEquityCarryingAmount',
                    'RedeemableNoncontrollingInterestEquityFairValue'
                    ]
    
    balance_cols += validation_cols
    balance_cols += minority_equity_cols
    
    data = get_numbers(year, balance_cols)
    
    # condense minority equity and set default to zero
    data['TotalMinorityEquity'] = data[minority_equity_cols].fillna(0.).sum(axis=1)
    data['TotalMinorityEquity_notes'] = pd.Series(dtype='string')

    return data

def income_data():
    cash_flow_cols = ['Revenues', 'CostOfRevenue', 'GrossProfit',
                      'OperatingExpenses', 'OperatingIncomeLoss',
                      'CommonStockDividendsPerShareDeclared',
                      'ProfitLoss', 'NetIncomeLoss'
                      ]

    validation_cols = ['PreferredStockDividendsIncomeStatementImpact',
                       'NetIncomeLossAvailableToCommonStockholdersBasic'
                       ]

    minority_income_cols = [
                         'NetIncomeLossAttributableToNoncontrollingInterest',
                         'NetIncomeLossAttributableToNoncontrollingInterestOfSubsidiary'
                        ]

    revenue_synonyms = ['Revenues', 'RevenueFromContractWithCustomerExcludingAssessedTax']
    cost_synonyms = ['CostOfRevenue', 'CostOfGoodsAndServicesSold']
    operating_cost_synonyms = ['OperatingExpenses', 'SellingGeneralAndAdministrativeExpense']

    cash_flow_cols += validation_cols
    cash_flow_cols += minority_income_cols
    cash_flow_cols += revenue_synonyms[1:]
    cash_flow_cols += cost_synonyms[1:]
    cash_flow_cols += operating_cost_synonyms[1:]

    data = get_numbers(year, cash_flow_cols)

    return data

# %%
subs = get_submissions(2022)

# %% [markdown]
# ### Apple

# %%
data = income_data()

# %%
apple_data = data.loc[subs[subs['name'] == 'APPLE INC'].index[0]]

# %%
apple_data
# Out:
# CommonStockDividendsPerShareDeclared                                              0.9
# CostOfGoodsAndServicesSold                                             223546000000.0
# CostOfRevenue                                                                     NaN
# GrossProfit                                                            170782000000.0
# NetIncomeLoss                                                           99803000000.0
# NetIncomeLossAttributableToNoncontrollingInterest                                 NaN
# NetIncomeLossAttributableToNoncontrollingInterestOfSubsidiary                     NaN
# NetIncomeLossAvailableToCommonStockholdersBasic                                   NaN
# OperatingExpenses                                                       51345000000.0
# OperatingIncomeLoss                                                    119437000000.0
# PreferredStockDividendsIncomeStatementImpact                                      NaN
# ProfitLoss                                                                        NaN
# RevenueFromContractWithCustomerExcludingAssessedTax                    394328000000.0
# Revenues                                                                          NaN
# SellingGeneralAndAdministrativeExpense                                  25094000000.0
# CommonStockDividendsPerShareDeclared_notes                                       <NA>
# CostOfGoodsAndServicesSold_notes                                                 <NA>
# CostOfRevenue_notes                                                              <NA>
# GrossProfit_notes                                                                <NA>
# NetIncomeLoss_notes                                                              <NA>
# NetIncomeLossAttributableToNoncontrollingInterest_notes                          <NA>
# NetIncomeLossAttributableToNoncontrollingInterestOfSubsidiary_notes              <NA>
# NetIncomeLossAvailableToCommonStockholdersBasic_notes                            <NA>
# OperatingExpenses_notes                                                          <NA>
# OperatingIncomeLoss_notes                                                        <NA>
# PreferredStockDividendsIncomeStatementImpact_notes                               <NA>
# ProfitLoss_notes                                                                 <NA>
# RevenueFromContractWithCustomerExcludingAssessedTax_notes                        <NA>
# Revenues_notes                                                                   <NA>
# SellingGeneralAndAdministrativeExpense_notes                                     <NA>
# Name: 0000320193-22-000108, dtype: object

# %% [markdown]
# The issue here is that we have _both_ `OperatingExpenses` and `SellingGeneralAndAdministrativeExpense` which is a sub-item of operating expenses.

# %%
data[data['Revenues'].isna()]
# Out:
#                       CommonStockDividendsPerShareDeclared  \
# adsh
# 0000002488-23-000047                                   NaN
# 0000003545-23-000030                                   2.0
# 0000004127-22-000038                                   2.3
# 0000004127-23-000030                                   2.3
# 0000004281-23-000004                                   0.1
# ...                                                    ...
# 0001929980-23-000010                                   NaN
# 0001935979-23-000009                                   NaN
# 0001937653-23-000011                                   NaN
# 0001944558-23-000024                                   NaN
# 0001999371-23-000633                                   NaN
#
#                       CostOfGoodsAndServicesSold  CostOfRevenue   GrossProfit  \
# adsh
# 0000002488-23-000047                1.299800e+10            NaN  1.060300e+10
# 0000003545-23-000030                         NaN            NaN -1.476500e+07
# 0000004127-22-000038                2.881200e+09            NaN  2.604300e+09
# 0000004127-23-000030                2.881200e+09            NaN  2.604300e+09
# 0000004281-23-000004                         NaN            NaN           NaN
# ...                                          ...            ...           ...
# 0001929980-23-000010                         NaN            NaN           NaN
# 0001935979-23-000009                         NaN            NaN           NaN
# 0001937653-23-000011                         NaN            NaN           NaN
# 0001944558-23-000024                         NaN            NaN           NaN
# 0001999371-23-000633                         NaN            NaN           NaN
#
#                       NetIncomeLoss  \
# adsh
# 0000002488-23-000047   1.320000e+09
# 0000003545-23-000030   1.245900e+07
# 0000004127-22-000038   1.275200e+09
# 0000004127-23-000030   1.275200e+09
# 0000004281-23-000004   4.690000e+08
# ...                             ...
# 0001929980-23-000010  -1.239600e+05
# 0001935979-23-000009  -5.702790e+08
# 0001937653-23-000011   1.243410e+08
# 0001944558-23-000024   1.189030e+08
# 0001999371-23-000633  -2.903739e+06
#
#                       NetIncomeLossAttributableToNoncontrollingInterest  \
# adsh
# 0000002488-23-000047                                                NaN
# 0000003545-23-000030                                          -573000.0
# 0000004127-22-000038                                                NaN
# 0000004127-23-000030                                                NaN
# 0000004281-23-000004                                                NaN
# ...                                                                 ...
# 0001929980-23-000010                                                NaN
# 0001935979-23-000009                                                NaN
# 0001937653-23-000011                                                NaN
# 0001944558-23-000024                                                NaN
# 0001999371-23-000633                                                NaN
#
#                       NetIncomeLossAttributableToNoncontrollingInterestOfSubsidiary  \
# adsh
# 0000002488-23-000047                                                NaN
# 0000003545-23-000030                                                NaN
# 0000004127-22-000038                                                NaN
# 0000004127-23-000030                                                NaN
# 0000004281-23-000004                                                NaN
# ...                                                                 ...
# 0001929980-23-000010                                                NaN
# 0001935979-23-000009                                                NaN
# 0001937653-23-000011                                                NaN
# 0001944558-23-000024                                                NaN
# 0001999371-23-000633                                                NaN
#
#                       NetIncomeLossAvailableToCommonStockholdersBasic  \
# adsh
# 0000002488-23-000047                                              NaN
# 0000003545-23-000030                                              NaN
# 0000004127-22-000038                                              NaN
# 0000004127-23-000030                                              NaN
# 0000004281-23-000004                                      467000000.0
# ...                                                               ...
# 0001929980-23-000010                                              NaN
# 0001935979-23-000009                                              NaN
# 0001937653-23-000011                                      124341000.0
# 0001944558-23-000024                                      115897000.0
# 0001999371-23-000633                                              NaN
#
#                       OperatingExpenses  OperatingIncomeLoss  ...  \
# adsh                                                          ...
# 0000002488-23-000047                NaN         1.264000e+09  ...
# 0000003545-23-000030                NaN        -2.484400e+07  ...
# 0000004127-22-000038       1.077300e+09         1.527000e+09  ...
# 0000004127-23-000030       1.077300e+09         1.527000e+09  ...
# 0000004281-23-000004                NaN         9.190000e+08  ...
# ...                                 ...                  ...  ...
# 0001929980-23-000010                NaN        -1.373110e+05  ...
# 0001935979-23-000009       5.679320e+08        -5.679320e+08  ...
# 0001937653-23-000011                NaN         1.305280e+08  ...
# 0001944558-23-000024       1.462040e+08         1.538660e+08  ...
# 0001999371-23-000633       2.911189e+06        -2.911189e+06  ...
#
#                       NetIncomeLossAttributableToNoncontrollingInterest_notes  \
# adsh
# 0000002488-23-000047                                               <NA>
# 0000003545-23-000030                                               <NA>
# 0000004127-22-000038                                               <NA>
# 0000004127-23-000030                                               <NA>
# 0000004281-23-000004                                               <NA>
# ...                                                                 ...
# 0001929980-23-000010                                               <NA>
# 0001935979-23-000009                                               <NA>
# 0001937653-23-000011                                               <NA>
# 0001944558-23-000024                                               <NA>
# 0001999371-23-000633                                               <NA>
#
#                       NetIncomeLossAttributableToNoncontrollingInterestOfSubsidiary_notes  \
# adsh
# 0000002488-23-000047                                               <NA>
# 0000003545-23-000030                                               <NA>
# 0000004127-22-000038                                               <NA>
# 0000004127-23-000030                                               <NA>
# 0000004281-23-000004                                               <NA>
# ...                                                                 ...
# 0001929980-23-000010                                               <NA>
# 0001935979-23-000009                                               <NA>
# 0001937653-23-000011                                               <NA>
# 0001944558-23-000024                                               <NA>
# 0001999371-23-000633                                               <NA>
#
#                       NetIncomeLossAvailableToCommonStockholdersBasic_notes  \
# adsh
# 0000002488-23-000047                                               <NA>
# 0000003545-23-000030                                               <NA>
# 0000004127-22-000038                                               <NA>
# 0000004127-23-000030                                               <NA>
# 0000004281-23-000004                                               <NA>
# ...                                                                 ...
# 0001929980-23-000010                                               <NA>
# 0001935979-23-000009                                               <NA>
# 0001937653-23-000011                                               <NA>
# 0001944558-23-000024                                               <NA>
# 0001999371-23-000633                                               <NA>
#
#                       OperatingExpenses_notes  OperatingIncomeLoss_notes  \
# adsh
# 0000002488-23-000047                     <NA>                       <NA>
# 0000003545-23-000030                     <NA>                       <NA>
# 0000004127-22-000038                     <NA>                       <NA>
# 0000004127-23-000030                     <NA>                       <NA>
# 0000004281-23-000004                     <NA>                       <NA>
# ...                                       ...                        ...
# 0001929980-23-000010                     <NA>                       <NA>
# 0001935979-23-000009                     <NA>                       <NA>
# 0001937653-23-000011                     <NA>                       <NA>
# 0001944558-23-000024                     <NA>                       <NA>
# 0001999371-23-000633                     <NA>                       <NA>
#
#                      PreferredStockDividendsIncomeStatementImpact_notes  \
# adsh
# 0000002488-23-000047                                               <NA>
# 0000003545-23-000030                                               <NA>
# 0000004127-22-000038                                               <NA>
# 0000004127-23-000030                                               <NA>
# 0000004281-23-000004                                               <NA>
# ...                                                                 ...
# 0001929980-23-000010                                               <NA>
# 0001935979-23-000009                                               <NA>
# 0001937653-23-000011                                               <NA>
# 0001944558-23-000024                                               <NA>
# 0001999371-23-000633                                               <NA>
#
#                      ProfitLoss_notes  \
# adsh
# 0000002488-23-000047             <NA>
# 0000003545-23-000030             <NA>
# 0000004127-22-000038             <NA>
# 0000004127-23-000030             <NA>
# 0000004281-23-000004             <NA>
# ...                               ...
# 0001929980-23-000010             <NA>
# 0001935979-23-000009             <NA>
# 0001937653-23-000011             <NA>
# 0001944558-23-000024             <NA>
# 0001999371-23-000633             <NA>
#
#                      RevenueFromContractWithCustomerExcludingAssessedTax_notes  \
# adsh
# 0000002488-23-000047                                               <NA>
# 0000003545-23-000030                                               <NA>
# 0000004127-22-000038                                               <NA>
# 0000004127-23-000030                                               <NA>
# 0000004281-23-000004                                               <NA>
# ...                                                                 ...
# 0001929980-23-000010                                               <NA>
# 0001935979-23-000009                                               <NA>
# 0001937653-23-000011                                               <NA>
# 0001944558-23-000024                                               <NA>
# 0001999371-23-000633                                               <NA>
#
#                      Revenues_notes  \
# adsh
# 0000002488-23-000047           <NA>
# 0000003545-23-000030           <NA>
# 0000004127-22-000038           <NA>
# 0000004127-23-000030           <NA>
# 0000004281-23-000004           <NA>
# ...                             ...
# 0001929980-23-000010           <NA>
# 0001935979-23-000009           <NA>
# 0001937653-23-000011           <NA>
# 0001944558-23-000024           <NA>
# 0001999371-23-000633           <NA>
#
#                      SellingGeneralAndAdministrativeExpense_notes
# adsh
# 0000002488-23-000047                                         <NA>
# 0000003545-23-000030                                         <NA>
# 0000004127-22-000038                                         <NA>
# 0000004127-23-000030                                         <NA>
# 0000004281-23-000004                                         <NA>
# ...                                                           ...
# 0001929980-23-000010                                         <NA>
# 0001935979-23-000009                                         <NA>
# 0001937653-23-000011                                         <NA>
# 0001944558-23-000024                                         <NA>
# 0001999371-23-000633                                         <NA>
#
# [4671 rows x 30 columns]

# %%
# %run finance_logic.py

# %%
test = SubFields('Revenues', ['RevenueFromContractWithCustomerExcludingAssessedTax'])
d2 = test.impute_parent(data)
d2['Revenues'].isna().any()
# Out:
# False

# %% [markdown]
# Nice. Fixed for now.

# %% [markdown]
# ### General Mills
#
# This is an egregious example of the data being incorrectly fetched: the revenue is totally wrong compared to the statement.

# %%
raw_data = get_raw_data(2022, ['Revenues'])

# %%
adsh = subs[subs['name'] == 'GENERAL MILLS INC'].index[0]

# %%
raw_data[ raw_data['adsh'] == adsh]
# Out:
#                     adsh       tag       ddate dyear       version coreg qtrs  \
# 82  0001193125-22-185257  Revenues  2022-05-31  2022  us-gaap/2021  None    4
#
#     uom         value footnote
# 82  USD  2.134300e+09     None

# %%
con = sqlite3.connect('data/processed/all10k.db')
query = """ SELECT * FROM num
             WHERE (dyear=:year) AND (adsh=:adsh);
        """

data = pd.read_sql_query(query, con, params={'year': 2022, 'adsh': '0001193125-22-185257'},
                         dtype={'value': float, 'adsh': str})

# %%
data[ data['tag'] == 'Revenues']
# Out:
#                      adsh       tag       version coreg       ddate qtrs  uom  \
# 280  0001193125-22-185257  Revenues  us-gaap/2021  None  2022-05-31    4  USD
#
#             value footnote dyear
# 280  2.134300e+09     None  2022

# %%
data[ data['tag'] == 'RevenueFromContractWithCustomerExcludingAssessedTax']
# Out:
#                      adsh                                                tag  \
# 277  0001193125-22-185257  RevenueFromContractWithCustomerExcludingAssess...
# 278  0001193125-22-185257  RevenueFromContractWithCustomerExcludingAssess...
# 279  0001193125-22-185257  RevenueFromContractWithCustomerExcludingAssess...
#
#           version coreg       ddate qtrs  uom         value footnote dyear
# 277  us-gaap/2021  None  2022-05-31    4  USD  1.899280e+10     None  2022
# 278  us-gaap/2021  None  2022-02-28    1  USD  4.537700e+09     None  2022
# 279  us-gaap/2021  None  2022-05-31    1  USD  4.891200e+09     None  2022

# %% [markdown]
# Ok, this is extremely annoying! Revenues is reported for a subsidiary, while RevenueFrom.. is reported for the parent company. There is apparently no metadata that tells the two apart. I think this should be represented in the coreg field, but seems to have been left out!
#
# I think the solution here is to take the subfield if it is larger than the parent.
